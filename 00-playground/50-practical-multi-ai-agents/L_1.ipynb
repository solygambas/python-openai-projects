# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# **Comprehensive Breakdown of Website Project Tasks**
#
# **Project Title:** Create a Website for a Small Business
# **Project Duration:** 12 weeks
#
# ### Task Breakdown
#
# 1. **Define Website Requirements**
#    - **Description:** Conduct meetings with stakeholders to gather comprehensive requirements.
#    - **Responsibility:** John Doe (Project Manager)
#    - **Timeline:** Week 1
#    - **Dependencies:** None
#    - **Deliverables:** Requirement Specification Document
#
# 2. **Create Wireframes & Mockups**
#    - **Description:** Develop initial wireframes and high-fidelity mockups for review.
#    - **Responsibility:** Bob Smith (Designer)
#    - **Timeline:** Week 2
#    - **Dependencies:** Task 1
#    - **Deliverables:** Wireframe and Mockup Designs
#
# 3. **Develop Responsive Design**
#    - **Description:** Create a responsive web design that works on desktop and mobile devices.
#    - **Responsibility:** Bob Smith (Designer) & Jane Doe (Software Engineer)
#    - **Timeline:** Weeks 3-4
#    - **Dependencies:** Task 2
#    - **Deliverables:** Responsive Web Design Files
#
# 4. **Implement User Interface**
#    - **Description:** Implement a modern and visually appealing user interface.
#    - **Responsibility:** Jane Doe (Software Engineer)
#    - **Timeline:** Weeks 4-5
#    - **Dependencies:** Task 3
#    - **Deliverables:** Functional UI Components
#
# 5. **Develop Navigation System**
#    - **Description:** Create a user-friendly navigation system with an intuitive menu structure.
#    - **Responsibility:** Jane Doe (Software Engineer)
#    - **Timeline:** Week 6
#    - **Dependencies:** Task 4
#    - **Deliverables:** Navigation Functionality
#
# 6. **Create About Us Page**
#    - **Description:** Design and develop the "About Us" page.
#    - **Responsibility:** Bob Smith (Designer) & Jane Doe (Software Engineer)
#    - **Timeline:** Week 6
#    - **Dependencies:** Task 4
#    - **Deliverables:** About Us Page
#
# 7. **Design Services Page**
#    - **Description:** Develop a "Services" page showcasing business offerings and descriptions.
#    - **Responsibility:** Bob Smith (Designer) & Jane Doe (Software Engineer)
#    - **Timeline:** Week 7
#    - **Dependencies:** Task 6
#    - **Deliverables:** Services Page
#
# 8. **Create Contact Us Page**
#    - **Description:** Implement a "Contact Us" page with a form and integrated map.
#    - **Responsibility:** Bob Smith (Designer) & Jane Doe (Software Engineer)
#    - **Timeline:** Week 8
#    - **Dependencies:** Task 7
#    - **Deliverables:** Contact Us Page
#
# 9. **Implement Blog Section**
#    - **Description:** Develop a section for company blogs and updates.
#    - **Responsibility:** Jane Doe (Software Engineer)
#    - **Timeline:** Week 9
#    - **Dependencies:** Task 8
#    - **Deliverables:** Blog Section
#
# 10. **Optimize for SEO and Loading Times**
#     - **Description:** Work on SEO optimization and ensuring fast load times.
#     - **Responsibility:** Jane Doe (Software Engineer) & Alice Johnson (QA Engineer)
#     - **Timeline:** Week 10
#     - **Dependencies:** Task 9
#     - **Deliverables:** SEO Optimization Report
#
# 11. **Integrate Social Media Links**
#     - **Description:** Add social media links and sharing capabilities.
#     - **Responsibility:** Jane Doe (Software Engineer)
#     - **Timeline:** Week 10
#     - **Dependencies:** Task 9
#     - **Deliverables:** Social Media Integration
#
# 12. **Create Testimonials Section**
#     - **Description:** Develop a section for displaying testimonials from customers.
#     - **Responsibility:** Bob Smith (Designer) & Jane Doe (Software Engineer)
#     - **Timeline:** Week 11
#     - **Dependencies:** Task 11
#     - **Deliverables:** Testimonials Section
#
# 13. **Quality Assurance Testing**
#     - **Description:** Conduct thorough QA to ensure all functionalities are working as expected.
#     - **Responsibility:** Alice Johnson & Tom Brown (QA Engineers)
#     - **Timeline:** Week 11
#     - **Dependencies:** Task 12
#     - **Deliverables:** QA Report
#
# 14. **Final Review and Launch Preparation**
#     - **Description:** Final review of the website with stakeholders; prepare for launch.
#     - **Responsibility:** John Doe (Project Manager) & All Team Members
#     - **Timeline:** Week 12
#     - **Dependencies:** Task 13
#     - **Deliverables:** Go-Live Approval Document
#
# 15. **Website Launch**
#     - **Description:** Launch the website and monitor initial performance.
#     - **Responsibility:** John Doe (Project Manager)
#     - **Timeline:** End of Week 12
#     - **Dependencies:** Task 14
#     - **Deliverables:** Live Website
#
# ### Timeline Visualization (Gantt Chart)
#
# | Task                          | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 | Week 7 | Week 8 | Week 9 | Week 10 | Week 11 | Week 12 |
# |-------------------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|---------|---------|
# | Define Website Requirements    | █      |        |        |        |        |        |        |        |        |         |         |         |
# | Create Wireframes & Mockups    |        | █      |        |        |        |        |        |        |        |         |         |         |
# | Develop Responsive Design      |        |        | █      | █      |        |        |        |        |        |         |         |         |
# | Implement User Interface       |        |        |        | █      | █      |        |        |        |        |         |         |         |
# | Develop Navigation System      |        |        |        |        |        | █      |        |        |        |         |         |         |
# | Create About Us Page          |        |        |        |        |        | █      |        |        |        |         |         |         |
# | Design Services Page          |        |        |        |        |        |        | █      |        |        |         |         |         |
# | Create Contact Us Page        |        |        |        |        |        |        |        | █      |        |         |         |         |
# | Implement Blog Section        |        |        |        |        |        |        |        |        | █      |         |         |         |
# | Optimize for SEO and Loading  |        |        |        |        |        |        |        |        |        | █       |         |         |
# | Integrate Social Media Links   |        |        |        |        |        |        |        |        |        | █       |         |         |
# | Create Testimonials Section    |        |        |        |        |        |        |        |        |        |         | █       |         |
# | Quality Assurance Testing      |        |        |        |        |        |        |        |        |        |         | █       |         |
# | Final Review and Launch Prep   |        |        |        |        |        |        |        |        |        |         |         | █       |
# | Website Launch                |        |        |        |        |        |        |        |        |        |         |         | █       |
#
# This detailed breakdown ensures clarity in project execution, tracks progress, and aligns team members with their responsibilities, delivering a website that not only meets the business needs but also exceeds expectations in visual appeal and functionality.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# **Project Title:** Create a Website for a Small Business
# **Project Duration:** 12 weeks
#
# #### Task Breakdown Overview
#
# 1. **Define Website Requirements**
#    - **Estimated Time:** 16 hours
#    - **Resources Required:** 1 Project Manager (John Doe)
#    - **Effort:** Low Complexity (Clear stakeholder involvement)
#    - **Risks/Uncertainties:** Stakeholder availability may impact timeline.
#
# 2. **Create Wireframes & Mockups**
#    - **Estimated Time:** 24 hours
#    - **Resources Required:** 1 Designer (Bob Smith)
#    - **Effort:** Medium Complexity (Requires iterative feedback process)
#    - **Risks/Uncertainties:** Potential rework if initial designs do not meet requirements or generate differing expectations.
#
# 3. **Develop Responsive Design**
#    - **Estimated Time:** 48 hours
#    - **Resources Required:** 1 Designer (Bob Smith), 1 Software Engineer (Jane Doe)
#    - **Effort:** High Complexity (Multiple breakpoints for different devices)
#    - **Risks/Uncertainties:** Compatibility issues across devices can arise, potentially causing delays.
#
# 4. **Implement User Interface**
#    - **Estimated Time:** 40 hours
#    - **Resources Required:** 1 Software Engineer (Jane Doe)
#    - **Effort:** Medium Complexity (Requires quality UI components and integrations)
#    - **Risks/Uncertainties:** Unexpected design changes may prolong implementation.
#
# 5. **Develop Navigation System**
#    - **Estimated Time:** 24 hours
#    - **Resources Required:** 1 Software Engineer (Jane Doe)
#    - **Effort:** Low Complexity (Standard navigation design)
#    - **Risks/Uncertainties:** User testing feedback may necessitate modifications.
#
# 6. **Create About Us Page**
#    - **Estimated Time:** 20 hours
#    - **Resources Required:** 1 Designer (Bob Smith), 1 Software Engineer (Jane Doe)
#    - **Effort:** Low Complexity (Standard content-driven page)
#    - **Risks/Uncertainties:** Content approval from stakeholders necessary before development.
#
# 7. **Design Services Page**
#    - **Estimated Time:** 20 hours
#    - **Resources Required:** 1 Designer (Bob Smith), 1 Software Engineer (Jane Doe)
#    - **Effort:** Medium Complexity (Requires clear presentation of services)
#    - **Risks/Uncertainties:** Changes in service offerings can affect design and content.
#
# 8. **Create Contact Us Page**
#    - **Estimated Time:** 16 hours
#    - **Resources Required:** 1 Designer (Bob Smith), 1 Software Engineer (Jane Doe)
#    - **Effort:** Medium Complexity (Inclusion of forms and map integration)
#    - **Risks/Uncertainties:** Mapping service dependency can create delays if issues arise.
#
# 9. **Implement Blog Section**
#    - **Estimated Time:** 24 hours
#    - **Resources Required:** 1 Software Engineer (Jane Doe)
#    - **Effort:** Medium Complexity (Integration with back-end for posting and comments)
#    - **Risks/Uncertainties:** Technical issues with CMS integration may arise.
#
# 10. **Optimize for SEO and Loading Times**
#     - **Estimated Time:** 32 hours
#     - **Resources Required:** 1 Software Engineer (Jane Doe), 1 QA Engineer (Alice Johnson)
#     - **Effort:** High Complexity (Requires comprehensive analysis and implementation)
#     - **Risks/Uncertainties:** Continuous evolving SEO standards and practices can complicate effective implementation.
#
# 11. **Integrate Social Media Links**
#     - **Estimated Time:** 16 hours
#     - **Resources Required:** 1 Software Engineer (Jane Doe)
#     - **Effort:** Low Complexity (Basic integration of links)
#     - **Risks/Uncertainties:** None significant expected.
#
# 12. **Create Testimonials Section**
#     - **Estimated Time:** 20 hours
#     - **Resources Required:** 1 Designer (Bob Smith), 1 Software Engineer (Jane Doe)
#     - **Effort:** Medium Complexity (Require design and backend to collect/display testimonials)
#     - **Risks/Uncertainties:** Sustainability of testimonial content over time may require ongoing management.
#
# 13. **Quality Assurance Testing**
#     - **Estimated Time:** 40 hours
#     - **Resources Required:** 2 QA Engineers (Alice Johnson, Tom Brown)
#     - **Effort:** High Complexity (Thorough testing across devices/browsers)
#     - **Risks/Uncertainties:** Unforeseen bugs could require significant rework.
#
# 14. **Final Review and Launch Preparation**
#     - **Estimated Time:** 16 hours
#     - **Resources Required:** 1 Project Manager (John Doe), All Team Members
#     - **Effort:** Low Complexity (Organizational task with team input and review)
#     - **Risks/Uncertainties:** Delays if stakeholder feedback is not prompt.
#
# 15. **Website Launch**
#     - **Estimated Time:** 12 hours
#     - **Resources Required:** 1 Project Manager (John Doe)
#     - **Effort:** Low Complexity (Final execution step)
#     - **Risks/Uncertainties:** Possible last-minute issues could lead to delays.
#
# ### Summary of Risks and Uncertainties
# - Availability and prompt responses from stakeholders can delay the requirement gathering and content approval processes.
# - Changing business needs or unforeseen technical complexities may arise during the design and development phases, impacting the overall timeline.
# - QA testing may uncover significant functionality issues that could extend the project timeline, necessitating additional resources and time.
# - SEO optimization may require continuous adjustments to align with evolving search engine policies.
#
# ### Project Timeline Visualization
# This will closely resemble a Gantt chart indicating each task's duration and dependencies as outlined in the task breakdown.
#
# ---
#
# This detailed estimation report provides clarity and aligns team members with their responsibilities to ensure that the website is delivered efficiently, within budget, and meets the business needs effectively.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for Website Project
#
# | Task                                | Assigned Team Members        | Start Date | End Date   | Estimated Time |
# |-------------------------------------|------------------------------|------------|------------|----------------|
# | 1. Define Website Requirements       | John Doe                     | Week 1    | Week 1    | 16 hours       |
# | 2. Create Wireframes & Mockups      | Bob Smith                    | Week 1    | Week 2    | 24 hours       |
# | 3. Develop Responsive Design         | Bob Smith, Jane Doe          | Week 2    | Week 4    | 48 hours       |
# | 4. Implement User Interface          | Jane Doe                     | Week 4    | Week 5    | 40 hours       |
# | 5. Develop Navigation System         | Jane Doe                     | Week 5    | Week 5    | 24 hours       |
# | 6. Create About Us Page             | Bob Smith, Jane Doe          | Week 5    | Week 6    | 20 hours       |
# | 7. Design Services Page             | Bob Smith, Jane Doe          | Week 6    | Week 7    | 20 hours       |
# | 8. Create Contact Us Page           | Bob Smith, Jane Doe          | Week 7    | Week 8    | 16 hours       |
# | 9. Implement Blog Section            | Jane Doe                     | Week 8    | Week 9    | 24 hours       |
# | 10. Optimize for SEO and Loading Times| Jane Doe, Alice Johnson     | Week 9    | Week 10   | 32 hours       |
# | 11. Integrate Social Media Links     | Jane Doe                     | Week 10   | Week 10   | 16 hours       |
# | 12. Create Testimonials Section      | Bob Smith, Jane Doe          | Week 10   | Week 11   | 20 hours       |
# | 13. Quality Assurance Testing        | Alice Johnson, Tom Brown     | Week 11   | Week 12   | 40 hours       |
# | 14. Final Review and Launch Preparation| John Doe, All Team Members | Week 12   | Week 12   | 16 hours       |
# | 15. Website Launch                  | John Doe                     | Week 12   | Week 12   | 12 hours       |
#
# ### Summary of Allocation Rationale:
#
# 1. **Define Website Requirements**: Assigned to John Doe (Project Manager) as he is responsible for leading and ensuring stakeholder involvement.
#
# 2. **Create Wireframes & Mockups**: Bob Smith (Designer) has the appropriate skills to create initial visual designs that engage stakeholders.
#
# 3. **Develop Responsive Design**: Collaboration between Bob Smith and Jane Doe is essential due to the high complexity of responsive design, leveraging both design and development skills.
#
# 4. **Implement User Interface**: Jane Doe has the expertise needed to implement the UI elements, keeping in mind her prior involvement in responsive design.
#
# 5. **Develop Navigation System**: Jane Doe handles this straightforward task (low complexity) to maintain continuity in development.
#
# 6. **Create About Us Page**: Involving Jane Doe and Bob Smith again ensures a consistent approach to design and development for standard pages.
#
# 7. **Design Services Page**: Requires both design and development skills, thus Bob Smith and Jane Doe will collaborate to achieve the best outcome.
#
# 8. **Create Contact Us Page**: Similarly, this task involves design elements and interface development, justified involving both Bob Smith and Jane Doe.
#
# 9. **Implement Blog Section**: Jane Doe takes this on because of her corresponding software engineering experience, ensuring seamless CMS integration.
#
# 10. **Optimize for SEO and Loading Times**: This task demands both coding and quality assessment expertise—Jane Doe along with QA Engineer Alice Johnson will ensure every aspect of the website is optimized.
#
# 11. **Integrate Social Media Links**: A straightforward task assigned to Jane Doe, who can efficiently carry it out given her ongoing familiarity with website architecture.
#
# 12. **Create Testimonials Section**: A joint effort between Jane Doe and Bob Smith is necessary to design the front-end experience and manage backend solutions.
#
# 13. **Quality Assurance Testing**: Both QA Engineers, Alice Johnson and Tom Brown, are essential to ensure thorough testing across all website functionality.
#
# 14. **Final Review and Launch Preparation**: John Doe will lead this process, ensuring comprehensive input from team members to finalize the project details.
#
# 15. **Website Launch**: John Doe is responsible for executing the launch phase as he oversees the project's directive operations.
#
# This strategic allocation ensures that each task leverages the team member's strengths, complies with availability, and avoids overburdening any individual, setting the project for timely and successful completion.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0032
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         21225          12857               8368                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Define Website Requirements',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['John Doe']},
#   {'task_name': 'Create Wireframes & Mockups',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Develop Responsive Design',
#    'estimated_time_hours': 48.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']},
#   {'task_name': 'Implement User Interface',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Develop Navigation System',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create About Us Page',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']},
#   {'task_name': 'Design Services Page',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']},
#   {'task_name': 'Create Contact Us Page',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']},
#   {'task_name': 'Implement Blog Section',
#    'estimated_time_hours': 24.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Optimize for SEO and Loading Times',
#    'estimated_time_hours': 32.0,
#    'required_resources': ['Jane Doe', 'Alice Johnson']},
#   {'task_name': 'Integrate Social Media Links',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create Testimonials Section',
#    'estimated_time_hours': 20.0,
#    'required_resources': ['Bob Smith', 'Jane Doe']},
#   {'task_name': 'Quality Assurance Testing',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Final Review and Launch Preparation',
#    'estimated_time_hours': 16.0,
#    'required_resources': ['John Doe', 'All Team Members']},
#   {'task_name': 'Website Launch',
#    'estimated_time_hours': 12.0,
#    'required_resources': ['John Doe']}],
#  'milestones': [{'milestone_name': 'Phase 1 Completion', 'tasks': ['1', '2']},
#   {'milestone_name': 'Phase 2 Completion',
#    'tasks': ['3', '4', '5', '6', '7', '8']},
#   {'milestone_name': 'Phase 3 Completion', 'tasks': ['9', '10', '11', '12']},
#   {'milestone_name': 'Phase 4 Completion', 'tasks': ['13', '14', '15']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_a32e9 th {
#   font-size: 120%;
# }
# #T_a32e9  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_a32e9" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a32e9_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_a32e9_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_a32e9_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a32e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a32e9_row0_col0" class="data row0 col0" >Define Website Requirements</td>
#       <td id="T_a32e9_row0_col1" class="data row0 col1" >16.000000</td>
#       <td id="T_a32e9_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a32e9_row1_col0" class="data row1 col0" >Create Wireframes & Mockups</td>
#       <td id="T_a32e9_row1_col1" class="data row1 col1" >24.000000</td>
#       <td id="T_a32e9_row1_col2" class="data row1 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a32e9_row2_col0" class="data row2 col0" >Develop Responsive Design</td>
#       <td id="T_a32e9_row2_col1" class="data row2 col1" >48.000000</td>
#       <td id="T_a32e9_row2_col2" class="data row2 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a32e9_row3_col0" class="data row3 col0" >Implement User Interface</td>
#       <td id="T_a32e9_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_a32e9_row3_col2" class="data row3 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a32e9_row4_col0" class="data row4 col0" >Develop Navigation System</td>
#       <td id="T_a32e9_row4_col1" class="data row4 col1" >24.000000</td>
#       <td id="T_a32e9_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a32e9_row5_col0" class="data row5 col0" >Create About Us Page</td>
#       <td id="T_a32e9_row5_col1" class="data row5 col1" >20.000000</td>
#       <td id="T_a32e9_row5_col2" class="data row5 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a32e9_row6_col0" class="data row6 col0" >Design Services Page</td>
#       <td id="T_a32e9_row6_col1" class="data row6 col1" >20.000000</td>
#       <td id="T_a32e9_row6_col2" class="data row6 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a32e9_row7_col0" class="data row7 col0" >Create Contact Us Page</td>
#       <td id="T_a32e9_row7_col1" class="data row7 col1" >16.000000</td>
#       <td id="T_a32e9_row7_col2" class="data row7 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a32e9_row8_col0" class="data row8 col0" >Implement Blog Section</td>
#       <td id="T_a32e9_row8_col1" class="data row8 col1" >24.000000</td>
#       <td id="T_a32e9_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a32e9_row9_col0" class="data row9 col0" >Optimize for SEO and Loading Times</td>
#       <td id="T_a32e9_row9_col1" class="data row9 col1" >32.000000</td>
#       <td id="T_a32e9_row9_col2" class="data row9 col2" >['Jane Doe', 'Alice Johnson']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a32e9_row10_col0" class="data row10 col0" >Integrate Social Media Links</td>
#       <td id="T_a32e9_row10_col1" class="data row10 col1" >16.000000</td>
#       <td id="T_a32e9_row10_col2" class="data row10 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a32e9_row11_col0" class="data row11 col0" >Create Testimonials Section</td>
#       <td id="T_a32e9_row11_col1" class="data row11 col1" >20.000000</td>
#       <td id="T_a32e9_row11_col2" class="data row11 col2" >['Bob Smith', 'Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a32e9_row12_col0" class="data row12 col0" >Quality Assurance Testing</td>
#       <td id="T_a32e9_row12_col1" class="data row12 col1" >40.000000</td>
#       <td id="T_a32e9_row12_col2" class="data row12 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a32e9_row13_col0" class="data row13 col0" >Final Review and Launch Preparation</td>
#       <td id="T_a32e9_row13_col1" class="data row13 col1" >16.000000</td>
#       <td id="T_a32e9_row13_col2" class="data row13 col2" >['John Doe', 'All Team Members']</td>
#     </tr>
#     <tr>
#       <th id="T_a32e9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a32e9_row14_col0" class="data row14 col0" >Website Launch</td>
#       <td id="T_a32e9_row14_col1" class="data row14 col1" >12.000000</td>
#       <td id="T_a32e9_row14_col2" class="data row14 col2" >['John Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_fafbf th {
#   font-size: 120%;
# }
# #T_fafbf  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_fafbf" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fafbf_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_fafbf_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fafbf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fafbf_row0_col0" class="data row0 col0" >Phase 1 Completion</td>
#       <td id="T_fafbf_row0_col1" class="data row0 col1" >['1', '2']</td>
#     </tr>
#     <tr>
#       <th id="T_fafbf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fafbf_row1_col0" class="data row1 col0" >Phase 2 Completion</td>
#       <td id="T_fafbf_row1_col1" class="data row1 col1" >['3', '4', '5', '6', '7', '8']</td>
#     </tr>
#     <tr>
#       <th id="T_fafbf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fafbf_row2_col0" class="data row2 col0" >Phase 3 Completion</td>
#       <td id="T_fafbf_row2_col1" class="data row2 col1" >['9', '10', '11', '12']</td>
#     </tr>
#     <tr>
#       <th id="T_fafbf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fafbf_row3_col0" class="data row3 col0" >Phase 4 Completion</td>
#       <td id="T_fafbf_row3_col1" class="data row3 col1" >['13', '14', '15']</td>
#     </tr>
#   </tbody>
# </table>
