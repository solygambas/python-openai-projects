# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 220 packages in 1.88s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# jedi       ------------------------------     0 B/1.50 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# langchain  ------------------------------     0 B/987.87 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# regex      ------------------------------     0 B/774.15 KiB
# langchain  ------------------------------     0 B/987.87 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# langchain  ------------------------------     0 B/987.87 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# langchain  ------------------------------     0 B/987.87 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# langchain  ------------------------------     0 B/987.87 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# openai     ------------------------------     0 B/462.42 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# langchain  ------------------------------     0 B/987.87 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# huggingface-hub ------------------------------     0 B/457.12 KiB
# openai     ------------------------------     0 B/462.42 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# langchain  ------------------------------     0 B/987.87 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/457.12 KiB
# openai     ------------------------------     0 B/462.42 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# langchain  ------------------------------     0 B/987.87 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# pydantic   ------------------------------     0 B/421.58 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# huggingface-hub ------------------------------     0 B/457.12 KiB
# openai     ------------------------------     0 B/462.42 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# greenlet   ------------------------------     0 B/588.29 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# regex      ------------------------------     0 B/774.15 KiB
# langchain  ------------------------------     0 B/987.87 KiB
# pygments   ------------------------------     0 B/1.17 MiB
# jedi       ------------------------------     0 B/1.50 MiB
# aiohttp    ------------------------------     0 B/1.60 MiB
# networkx   ------------------------------     0 B/1.64 MiB
# kubernetes ------------------------------     0 B/1.90 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# google-cloud-resource-manager ------------------------------ 14.86 KiB/383.13 KiB
# langchain-core ------------------------------ 14.88 KiB/405.42 KiB
# pydantic   ------------------------------ 30.91 KiB/421.58 KiB
# watchfiles ------------------------------ 14.91 KiB/441.97 KiB
# httptools  ------------------------------ 62.91 KiB/449.01 KiB
# cffi       ------------------------------ 62.88 KiB/456.29 KiB
# huggingface-hub ------------------------------ 46.88 KiB/457.12 KiB
# openai     ------------------------------ 30.92 KiB/462.42 KiB
# pytz       ------------------------------ 30.88 KiB/496.10 KiB
# mpmath     ------------------------------ 61.48 KiB/523.63 KiB
# crewai-tools ------------------------------ 14.91 KiB/533.14 KiB
# greenlet   ------------------------------ 30.91 KiB/588.29 KiB
# chromadb   ------------------------------ 30.92 KiB/613.62 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 62.91 KiB/774.15 KiB
# ipython    ------------------------------ 24.53 KiB/807.34 KiB
# langchain  ------------------------------ 34.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 14.91 KiB/1.03 MiB
# pygments   ------------------------------ 30.88 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# google-cloud-resource-manager ------------------------------ 14.86 KiB/383.13 KiB
# langchain-core ------------------------------ 14.88 KiB/405.42 KiB
# pydantic   ------------------------------ 30.91 KiB/421.58 KiB
# watchfiles ------------------------------ 14.91 KiB/441.97 KiB
# httptools  ------------------------------ 94.91 KiB/449.01 KiB
# cffi       ------------------------------ 76.25 KiB/456.29 KiB
# huggingface-hub ------------------------------ 46.88 KiB/457.12 KiB
# openai     ------------------------------ 30.92 KiB/462.42 KiB
# pytz       ------------------------------ 30.88 KiB/496.10 KiB
# mpmath     ------------------------------ 78.52 KiB/523.63 KiB
# crewai-tools ------------------------------ 14.91 KiB/533.14 KiB
# greenlet   ------------------------------ 30.91 KiB/588.29 KiB
# chromadb   ------------------------------ 30.92 KiB/613.62 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 78.94 KiB/774.15 KiB
# ipython    ------------------------------ 24.53 KiB/807.34 KiB
# langchain  ------------------------------ 34.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 14.91 KiB/1.03 MiB
# pygments   ------------------------------ 30.88 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/213)
# google-cloud-resource-manager ------------------------------ 14.86 KiB/383.13 KiB
# langchain-core ------------------------------ 14.88 KiB/405.42 KiB
# pydantic   ------------------------------ 30.91 KiB/421.58 KiB
# watchfiles ------------------------------ 30.91 KiB/441.97 KiB
# httptools  ------------------------------ 142.91 KiB/449.01 KiB
# cffi       ------------------------------ 124.25 KiB/456.29 KiB
# huggingface-hub ------------------------------ 46.88 KiB/457.12 KiB
# openai     ------------------------------ 30.92 KiB/462.42 KiB
# pytz       ------------------------------ 30.88 KiB/496.10 KiB
# mpmath     ------------------------------ 126.52 KiB/523.63 KiB
# crewai-tools ------------------------------ 14.91 KiB/533.14 KiB
# greenlet   ------------------------------ 46.91 KiB/588.29 KiB
# chromadb   ------------------------------ 30.92 KiB/613.62 KiB
# pyvis      ------------------------------ 30.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# regex      ------------------------------ 126.94 KiB/774.15 KiB
# ipython    ------------------------------ 72.53 KiB/807.34 KiB
# langchain  ------------------------------ 34.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 110.91 KiB/1.03 MiB
# pygments   ------------------------------ 30.88 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/213)
# google-cloud-resource-manager ------------------------------ 46.86 KiB/383.13 KiB
# langchain-core ------------------------------ 30.88 KiB/405.42 KiB
# pydantic   ------------------------------ 78.66 KiB/421.58 KiB
# watchfiles ------------------------------ 222.09 KiB/441.97 KiB
# httptools  ------------------------------ 222.09 KiB/449.01 KiB
# cffi       ------------------------------ 204.25 KiB/456.29 KiB
# huggingface-hub ------------------------------ 77.38 KiB/457.12 KiB
# openai     ------------------------------ 62.82 KiB/462.42 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 142.52 KiB/523.63 KiB
# crewai-tools ------------------------------ 14.91 KiB/533.14 KiB
# greenlet   ------------------------------ 46.91 KiB/588.29 KiB
# chromadb   ------------------------------ 62.92 KiB/613.62 KiB
# pyvis      ------------------------------ 222.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 46.78 KiB/745.07 KiB
# regex      ------------------------------ 222.94 KiB/774.15 KiB
# ipython    ------------------------------ 94.89 KiB/807.34 KiB
# langchain  ------------------------------ 34.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 222.91 KiB/1.03 MiB
# pygments   ------------------------------ 76.24 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/213)
# google-cloud-resource-manager ------------------------------ 104.92 KiB/383.13 KiB
# langchain-core ------------------------------ 46.88 KiB/405.42 KiB
# pydantic   ------------------------------ 160.76 KiB/421.58 KiB
# watchfiles ------------------------------ 286.09 KiB/441.97 KiB
# httptools  ------------------------------ 286.09 KiB/449.01 KiB
# cffi       ------------------------------ 264.13 KiB/456.29 KiB
# huggingface-hub ------------------------------ 221.38 KiB/457.12 KiB
# openai     ------------------------------ 62.82 KiB/462.42 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 222.52 KiB/523.63 KiB
# crewai-tools ------------------------------ 24.05 KiB/533.14 KiB
# greenlet   ------------------------------ 174.47 KiB/588.29 KiB
# chromadb   ------------------------------ 78.92 KiB/613.62 KiB
# pyvis      ------------------------------ 286.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 268.20 KiB/745.07 KiB
# regex      ------------------------------ 270.94 KiB/774.15 KiB
# ipython    ------------------------------ 142.78 KiB/807.34 KiB
# langchain  ------------------------------ 34.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 270.91 KiB/1.03 MiB
# pygments   ------------------------------ 108.24 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/213)
# google-cloud-resource-manager ------------------------------ 158.86 KiB/383.13 KiB
# langchain-core ------------------------------ 62.88 KiB/405.42 KiB
# pydantic   ------------------------------ 192.76 KiB/421.58 KiB
# watchfiles ------------------------------ 350.09 KiB/441.97 KiB
# httptools  ------------------------------ 366.09 KiB/449.01 KiB
# cffi       ------------------------------ 324.56 KiB/456.29 KiB
# huggingface-hub ------------------------------ 237.38 KiB/457.12 KiB
# openai     ------------------------------ 78.82 KiB/462.42 KiB
# pytz       ------------------------------ 46.88 KiB/496.10 KiB
# mpmath     ------------------------------ 303.10 KiB/523.63 KiB
# crewai-tools ------------------------------ 39.94 KiB/533.14 KiB
# greenlet   ------------------------------ 334.47 KiB/588.29 KiB
# chromadb   ------------------------------ 94.92 KiB/613.62 KiB
# pyvis      ------------------------------ 350.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 348.20 KiB/745.07 KiB
# regex      ------------------------------ 334.94 KiB/774.15 KiB
# ipython    ------------------------------ 238.07 KiB/807.34 KiB
# langchain  ------------------------------ 50.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 334.91 KiB/1.03 MiB
# pygments   ------------------------------ 220.24 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/213)
# google-cloud-resource-manager ------------------------------ 238.04 KiB/383.13 KiB
# langchain-core ------------------------------ 110.88 KiB/405.42 KiB
# pydantic   ------------------------------ 254.66 KiB/421.58 KiB
# watchfiles ------------------------------ 426.08 KiB/441.97 KiB
# httptools  ------------------------------ 449.01 KiB/449.01 KiB
# cffi       ------------------------------ 380.25 KiB/456.29 KiB
# huggingface-hub ------------------------------ 317.38 KiB/457.12 KiB
# openai     ------------------------------ 78.82 KiB/462.42 KiB
# pytz       ------------------------------ 110.88 KiB/496.10 KiB
# mpmath     ------------------------------ 398.52 KiB/523.63 KiB
# crewai-tools ------------------------------ 55.94 KiB/533.14 KiB
# greenlet   ------------------------------ 406.24 KiB/588.29 KiB
# chromadb   ------------------------------ 286.09 KiB/613.62 KiB
# pyvis      ------------------------------ 424.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 414.77 KiB/745.07 KiB
# regex      ------------------------------ 430.94 KiB/774.15 KiB
# ipython    ------------------------------ 318.07 KiB/807.34 KiB
# langchain  ------------------------------ 50.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 395.59 KiB/1.03 MiB
# pygments   ------------------------------ 348.24 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/213)
# google-cloud-resource-manager ------------------------------ 238.04 KiB/383.13 KiB
# langchain-core ------------------------------ 110.88 KiB/405.42 KiB
# pydantic   ------------------------------ 270.66 KiB/421.58 KiB
# watchfiles ------------------------------ 426.08 KiB/441.97 KiB
# cffi       ------------------------------ 396.25 KiB/456.29 KiB
# huggingface-hub ------------------------------ 333.38 KiB/457.12 KiB
# openai     ------------------------------ 94.92 KiB/462.42 KiB
# pytz       ------------------------------ 110.88 KiB/496.10 KiB
# mpmath     ------------------------------ 398.52 KiB/523.63 KiB
# crewai-tools ------------------------------ 55.94 KiB/533.14 KiB
# greenlet   ------------------------------ 406.24 KiB/588.29 KiB
# chromadb   ------------------------------ 286.09 KiB/613.62 KiB
# pyvis      ------------------------------ 439.47 KiB/738.32 KiB
# pyyaml     ------------------------------ 430.66 KiB/745.07 KiB
# regex      ------------------------------ 430.94 KiB/774.15 KiB
# ipython    ------------------------------ 334.07 KiB/807.34 KiB
# langchain  ------------------------------ 50.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 411.59 KiB/1.03 MiB
# pygments   ------------------------------ 348.24 KiB/1.17 MiB
# jedi       ------------------------------ 171.89 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/213)
# google-cloud-resource-manager ------------------------------ 253.93 KiB/383.13 KiB
# langchain-core ------------------------------ 126.88 KiB/405.42 KiB
# pydantic   ------------------------------ 270.66 KiB/421.58 KiB
# cffi       ------------------------------ 412.25 KiB/456.29 KiB
# huggingface-hub ------------------------------ 333.38 KiB/457.12 KiB
# openai     ------------------------------ 94.92 KiB/462.42 KiB
# pytz       ------------------------------ 110.88 KiB/496.10 KiB
# mpmath     ------------------------------ 414.52 KiB/523.63 KiB
# crewai-tools ------------------------------ 78.91 KiB/533.14 KiB
# greenlet   ------------------------------ 422.24 KiB/588.29 KiB
# chromadb   ------------------------------ 286.09 KiB/613.62 KiB
# pyvis      ------------------------------ 455.47 KiB/738.32 KiB
# pyyaml     ------------------------------ 446.66 KiB/745.07 KiB
# regex      ------------------------------ 446.83 KiB/774.15 KiB
# ipython    ------------------------------ 350.07 KiB/807.34 KiB
# langchain  ------------------------------ 50.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 427.59 KiB/1.03 MiB
# pygments   ------------------------------ 348.24 KiB/1.17 MiB
# jedi       ------------------------------ 187.79 KiB/1.50 MiB
# aiohttp    ------------------------------ 472.51 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# rpds-py    ------------------------------ 16.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 14.88 KiB/378.73 KiB
# google-cloud-resource-manager ------------------------------ 315.19 KiB/383.13 KiB
# langchain-core ------------------------------ 142.88 KiB/405.42 KiB
# pydantic   ------------------------------ 303.75 KiB/421.58 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# huggingface-hub ------------------------------ 344.77 KiB/457.12 KiB
# openai     ------------------------------ 126.92 KiB/462.42 KiB
# pytz       ------------------------------ 110.88 KiB/496.10 KiB
# mpmath     ------------------------------ 478.52 KiB/523.63 KiB
# crewai-tools ------------------------------ 94.91 KiB/533.14 KiB
# greenlet   ------------------------------ 478.47 KiB/588.29 KiB
# chromadb   ------------------------------ 384.65 KiB/613.62 KiB
# pyvis      ------------------------------ 488.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 508.20 KiB/745.07 KiB
# regex      ------------------------------ 489.69 KiB/774.15 KiB
# ipython    ------------------------------ 366.07 KiB/807.34 KiB
# langchain  ------------------------------ 50.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 488.56 KiB/1.03 MiB
# pygments   ------------------------------ 396.24 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# rpds-py    ------------------------------ 48.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/378.73 KiB
# google-cloud-resource-manager ------------------------------ 331.19 KiB/383.13 KiB
# langchain-core ------------------------------ 158.88 KiB/405.42 KiB
# pydantic   ------------------------------ 319.75 KiB/421.58 KiB
# huggingface-hub ------------------------------ 344.77 KiB/457.12 KiB
# openai     ------------------------------ 142.92 KiB/462.42 KiB
# pytz       ------------------------------ 110.88 KiB/496.10 KiB
# mpmath     ------------------------------ 494.52 KiB/523.63 KiB
# crewai-tools ------------------------------ 378.14 KiB/533.14 KiB
# greenlet   ------------------------------ 494.47 KiB/588.29 KiB
# chromadb   ------------------------------ 398.09 KiB/613.62 KiB
# pyvis      ------------------------------ 502.46 KiB/738.32 KiB
# pyyaml     ------------------------------ 524.20 KiB/745.07 KiB
# regex      ------------------------------ 505.69 KiB/774.15 KiB
# ipython    ------------------------------ 366.07 KiB/807.34 KiB
# langchain  ------------------------------ 50.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 494.43 KiB/1.03 MiB
# pygments   ------------------------------ 417.66 KiB/1.17 MiB
# jedi       ------------------------------ 234.88 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# tzdata     ------------------------------ 14.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 128.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 77.41 KiB/378.73 KiB
# google-cloud-resource-manager ------------------------------ 382.04 KiB/383.13 KiB
# langchain-core ------------------------------ 190.55 KiB/405.42 KiB
# pydantic   ------------------------------ 390.75 KiB/421.58 KiB
# huggingface-hub ------------------------------ 376.77 KiB/457.12 KiB
# openai     ------------------------------ 174.92 KiB/462.42 KiB
# pytz       ------------------------------ 126.88 KiB/496.10 KiB
# mpmath     ------------------------------ 523.63 KiB/523.63 KiB
# crewai-tools ------------------------------ 458.14 KiB/533.14 KiB
# greenlet   ------------------------------ 542.47 KiB/588.29 KiB
# chromadb   ------------------------------ 414.09 KiB/613.62 KiB
# pyvis      ------------------------------ 578.35 KiB/738.32 KiB
# pyyaml     ------------------------------ 604.20 KiB/745.07 KiB
# regex      ------------------------------ 590.94 KiB/774.15 KiB
# ipython    ------------------------------ 414.07 KiB/807.34 KiB
# langchain  ------------------------------ 66.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 552.46 KiB/1.03 MiB
# pygments   ------------------------------ 476.24 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# tzdata     ------------------------------ 14.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 128.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 77.41 KiB/378.73 KiB
# langchain-core ------------------------------ 190.55 KiB/405.42 KiB
# pydantic   ------------------------------ 398.66 KiB/421.58 KiB
# huggingface-hub ------------------------------ 376.77 KiB/457.12 KiB
# openai     ------------------------------ 174.92 KiB/462.42 KiB
# pytz       ------------------------------ 126.88 KiB/496.10 KiB
# mpmath     ------------------------------ 523.63 KiB/523.63 KiB
# crewai-tools ------------------------------ 458.14 KiB/533.14 KiB
# greenlet   ------------------------------ 542.47 KiB/588.29 KiB
# chromadb   ------------------------------ 414.09 KiB/613.62 KiB
# pyvis      ------------------------------ 578.35 KiB/738.32 KiB
# pyyaml     ------------------------------ 604.20 KiB/745.07 KiB
# regex      ------------------------------ 590.94 KiB/774.15 KiB
# ipython    ------------------------------ 414.07 KiB/807.34 KiB
# langchain  ------------------------------ 66.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 552.46 KiB/1.03 MiB
# pygments   ------------------------------ 476.24 KiB/1.17 MiB
# jedi       ------------------------------ 234.88 KiB/1.50 MiB
# aiohttp    ------------------------------ 616.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# tzdata     ------------------------------ 14.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 138.23 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 93.41 KiB/378.73 KiB
# langchain-core ------------------------------ 190.55 KiB/405.42 KiB
# pydantic   ------------------------------ 414.66 KiB/421.58 KiB
# huggingface-hub ------------------------------ 392.77 KiB/457.12 KiB
# openai     ------------------------------ 190.92 KiB/462.42 KiB
# pytz       ------------------------------ 126.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 474.14 KiB/533.14 KiB
# greenlet   ------------------------------ 542.47 KiB/588.29 KiB
# chromadb   ------------------------------ 414.09 KiB/613.62 KiB
# pyvis      ------------------------------ 584.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 620.20 KiB/745.07 KiB
# regex      ------------------------------ 606.94 KiB/774.15 KiB
# ipython    ------------------------------ 430.07 KiB/807.34 KiB
# langchain  ------------------------------ 66.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 568.35 KiB/1.03 MiB
# pygments   ------------------------------ 476.24 KiB/1.17 MiB
# jedi       ------------------------------ 234.88 KiB/1.50 MiB
# aiohttp    ------------------------------ 632.56 KiB/1.60 MiB
# networkx   ------------------------------ 303.68 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# jiter      ------------------------------     0 B/337.45 KiB
# tzdata     ------------------------------ 14.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 154.23 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 93.41 KiB/378.73 KiB
# langchain-core ------------------------------ 206.55 KiB/405.42 KiB
# huggingface-hub ------------------------------ 392.77 KiB/457.12 KiB
# openai     ------------------------------ 206.82 KiB/462.42 KiB
# pytz       ------------------------------ 126.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 474.14 KiB/533.14 KiB
# greenlet   ------------------------------ 558.47 KiB/588.29 KiB
# chromadb   ------------------------------ 421.17 KiB/613.62 KiB
# pyvis      ------------------------------ 600.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 636.20 KiB/745.07 KiB
# regex      ------------------------------ 622.94 KiB/774.15 KiB
# ipython    ------------------------------ 430.07 KiB/807.34 KiB
# langchain  ------------------------------ 66.47 KiB/987.87 KiB
# tiktoken   ------------------------------ 584.35 KiB/1.03 MiB
# pygments   ------------------------------ 508.24 KiB/1.17 MiB
# jedi       ------------------------------ 250.88 KiB/1.50 MiB
# aiohttp    ------------------------------ 648.56 KiB/1.60 MiB
# networkx   ------------------------------ 303.68 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# protobuf   ------------------------------ 16.00 KiB/312.18 KiB
# yarl       ------------------------------ 32.00 KiB/336.08 KiB
# jiter      ------------------------------ 32.00 KiB/337.45 KiB
# tzdata     ------------------------------ 30.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 192.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 109.41 KiB/378.73 KiB
# langchain-core ------------------------------ 286.88 KiB/405.42 KiB
# huggingface-hub ------------------------------ 429.38 KiB/457.12 KiB
# openai     ------------------------------ 222.92 KiB/462.42 KiB
# pytz       ------------------------------ 126.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 493.53 KiB/533.14 KiB
# greenlet   ------------------------------ 574.47 KiB/588.29 KiB
# chromadb   ------------------------------ 453.07 KiB/613.62 KiB
# pyvis      ------------------------------ 639.37 KiB/738.32 KiB
# pyyaml     ------------------------------ 684.20 KiB/745.07 KiB
# regex      ------------------------------ 670.94 KiB/774.15 KiB
# ipython    ------------------------------ 478.07 KiB/807.34 KiB
# langchain  ------------------------------ 92.87 KiB/987.87 KiB
# tiktoken   ------------------------------ 632.56 KiB/1.03 MiB
# pygments   ------------------------------ 556.24 KiB/1.17 MiB
# jedi       ------------------------------ 250.88 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# protobuf   ------------------------------ 47.89 KiB/312.18 KiB
# yarl       ------------------------------ 53.34 KiB/336.08 KiB
# jiter      ------------------------------ 60.22 KiB/337.45 KiB
# tzdata     ------------------------------ 30.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 224.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 125.41 KiB/378.73 KiB
# langchain-core ------------------------------ 302.88 KiB/405.42 KiB
# openai     ------------------------------ 222.92 KiB/462.42 KiB
# pytz       ------------------------------ 126.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 493.53 KiB/533.14 KiB
# greenlet   ------------------------------ 581.38 KiB/588.29 KiB
# chromadb   ------------------------------ 464.18 KiB/613.62 KiB
# pyvis      ------------------------------ 664.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 716.20 KiB/745.07 KiB
# regex      ------------------------------ 695.53 KiB/774.15 KiB
# ipython    ------------------------------ 478.07 KiB/807.34 KiB
# langchain  ------------------------------ 108.77 KiB/987.87 KiB
# tiktoken   ------------------------------ 664.08 KiB/1.03 MiB
# pygments   ------------------------------ 579.68 KiB/1.17 MiB
# jedi       ------------------------------ 265.27 KiB/1.50 MiB
# aiohttp    ------------------------------ 728.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# langsmith  ------------------------------     0 B/304.50 KiB
# protobuf   ------------------------------ 76.88 KiB/312.18 KiB
# yarl       ------------------------------ 77.17 KiB/336.08 KiB
# jiter      ------------------------------ 76.22 KiB/337.45 KiB
# tzdata     ------------------------------ 30.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 256.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 125.41 KiB/378.73 KiB
# langchain-core ------------------------------ 318.88 KiB/405.42 KiB
# openai     ------------------------------ 238.92 KiB/462.42 KiB
# pytz       ------------------------------ 142.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 509.53 KiB/533.14 KiB
# chromadb   ------------------------------ 480.18 KiB/613.62 KiB
# pyvis      ------------------------------ 692.61 KiB/738.32 KiB
# pyyaml     ------------------------------ 732.20 KiB/745.07 KiB
# regex      ------------------------------ 727.53 KiB/774.15 KiB
# ipython    ------------------------------ 509.96 KiB/807.34 KiB
# langchain  ------------------------------ 108.77 KiB/987.87 KiB
# tiktoken   ------------------------------ 679.98 KiB/1.03 MiB
# pygments   ------------------------------ 597.50 KiB/1.17 MiB
# jedi       ------------------------------ 265.27 KiB/1.50 MiB
# aiohttp    ------------------------------ 744.46 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# langsmith  ------------------------------ 8.33 KiB/304.50 KiB
# protobuf   ------------------------------ 92.88 KiB/312.18 KiB
# yarl       ------------------------------ 93.17 KiB/336.08 KiB
# jiter      ------------------------------ 92.22 KiB/337.45 KiB
# tzdata     ------------------------------ 62.88 KiB/338.63 KiB
# rpds-py    ------------------------------ 272.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 141.41 KiB/378.73 KiB
# langchain-core ------------------------------ 318.88 KiB/405.42 KiB
# openai     ------------------------------ 238.92 KiB/462.42 KiB
# pytz       ------------------------------ 142.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 509.53 KiB/533.14 KiB
# chromadb   ------------------------------ 480.18 KiB/613.62 KiB
# pyvis      ------------------------------ 708.61 KiB/738.32 KiB
# regex      ------------------------------ 734.94 KiB/774.15 KiB
# ipython    ------------------------------ 512.74 KiB/807.34 KiB
# langchain  ------------------------------ 108.77 KiB/987.87 KiB
# tiktoken   ------------------------------ 695.98 KiB/1.03 MiB
# pygments   ------------------------------ 620.24 KiB/1.17 MiB
# jedi       ------------------------------ 265.27 KiB/1.50 MiB
# aiohttp    ------------------------------ 749.39 KiB/1.60 MiB
# networkx   ------------------------------ 384.15 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# langsmith  ------------------------------ 24.33 KiB/304.50 KiB
# protobuf   ------------------------------ 108.88 KiB/312.18 KiB
# yarl       ------------------------------ 104.02 KiB/336.08 KiB
# jiter      ------------------------------ 108.22 KiB/337.45 KiB
# tzdata     ------------------------------ 78.06 KiB/338.63 KiB
# rpds-py    ------------------------------ 288.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 141.41 KiB/378.73 KiB
# langchain-core ------------------------------ 334.88 KiB/405.42 KiB
# openai     ------------------------------ 238.92 KiB/462.42 KiB
# pytz       ------------------------------ 142.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 509.53 KiB/533.14 KiB
# chromadb   ------------------------------ 480.18 KiB/613.62 KiB
# pyvis      ------------------------------ 712.56 KiB/738.32 KiB
# regex      ------------------------------ 750.94 KiB/774.15 KiB
# ipython    ------------------------------ 574.07 KiB/807.34 KiB
# langchain  ------------------------------ 108.77 KiB/987.87 KiB
# tiktoken   ------------------------------ 711.98 KiB/1.03 MiB
# pygments   ------------------------------ 636.24 KiB/1.17 MiB
# jedi       ------------------------------ 265.27 KiB/1.50 MiB
# aiohttp    ------------------------------ 765.28 KiB/1.60 MiB
# networkx   ------------------------------ 399.68 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# pypdf      ------------------------------ 16.00 KiB/294.96 KiB
# qdrant-client ------------------------------ 14.88 KiB/299.49 KiB
# langsmith  ------------------------------ 24.33 KiB/304.50 KiB
# protobuf   ------------------------------ 124.88 KiB/312.18 KiB
# yarl       ------------------------------ 125.17 KiB/336.08 KiB
# jiter      ------------------------------ 140.22 KiB/337.45 KiB
# tzdata     ------------------------------ 78.06 KiB/338.63 KiB
# rpds-py    ------------------------------ 320.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 157.41 KiB/378.73 KiB
# langchain-core ------------------------------ 350.88 KiB/405.42 KiB
# openai     ------------------------------ 238.92 KiB/462.42 KiB
# pytz       ------------------------------ 142.88 KiB/496.10 KiB
# crewai-tools ------------------------------ 522.14 KiB/533.14 KiB
# chromadb   ------------------------------ 480.18 KiB/613.62 KiB
# pyvis      ------------------------------ 724.00 KiB/738.32 KiB
# ipython    ------------------------------ 574.07 KiB/807.34 KiB
# langchain  ------------------------------ 124.77 KiB/987.87 KiB
# tiktoken   ------------------------------ 716.51 KiB/1.03 MiB
# pygments   ------------------------------ 668.24 KiB/1.17 MiB
# jedi       ------------------------------ 265.27 KiB/1.50 MiB
# aiohttp    ------------------------------ 792.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# bcrypt     ------------------------------     0 B/277.50 KiB
# pypdf      ------------------------------ 48.00 KiB/294.96 KiB
# qdrant-client ------------------------------ 46.88 KiB/299.49 KiB
# langsmith  ------------------------------ 40.33 KiB/304.50 KiB
# protobuf   ------------------------------ 140.88 KiB/312.18 KiB
# yarl       ------------------------------ 141.17 KiB/336.08 KiB
# jiter      ------------------------------ 172.22 KiB/337.45 KiB
# tzdata     ------------------------------ 78.06 KiB/338.63 KiB
# rpds-py    ------------------------------ 336.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 167.18 KiB/378.73 KiB
# langchain-core ------------------------------ 366.88 KiB/405.42 KiB
# openai     ------------------------------ 238.92 KiB/462.42 KiB
# pytz       ------------------------------ 158.88 KiB/496.10 KiB
# chromadb   ------------------------------ 496.18 KiB/613.62 KiB
# pyvis      ------------------------------ 738.32 KiB/738.32 KiB
# ipython    ------------------------------ 574.07 KiB/807.34 KiB
# langchain  ------------------------------ 124.77 KiB/987.87 KiB
# tiktoken   ------------------------------ 736.40 KiB/1.03 MiB
# pygments   ------------------------------ 684.24 KiB/1.17 MiB
# jedi       ------------------------------ 265.27 KiB/1.50 MiB
# aiohttp    ------------------------------ 824.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# bcrypt     ------------------------------ 16.00 KiB/277.50 KiB
# pypdf      ------------------------------ 64.00 KiB/294.96 KiB
# qdrant-client ------------------------------ 46.88 KiB/299.49 KiB
# langsmith  ------------------------------ 48.00 KiB/304.50 KiB
# protobuf   ------------------------------ 156.88 KiB/312.18 KiB
# yarl       ------------------------------ 157.17 KiB/336.08 KiB
# jiter      ------------------------------ 183.55 KiB/337.45 KiB
# tzdata     ------------------------------ 78.06 KiB/338.63 KiB
# rpds-py    ------------------------------ 352.00 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 183.07 KiB/378.73 KiB
# langchain-core ------------------------------ 366.88 KiB/405.42 KiB
# openai     ------------------------------ 238.92 KiB/462.42 KiB
# pytz       ------------------------------ 158.88 KiB/496.10 KiB
# chromadb   ------------------------------ 496.18 KiB/613.62 KiB
# ipython    ------------------------------ 606.07 KiB/807.34 KiB
# langchain  ------------------------------ 124.77 KiB/987.87 KiB
# tiktoken   ------------------------------ 736.40 KiB/1.03 MiB
# pygments   ------------------------------ 748.24 KiB/1.17 MiB
# jedi       ------------------------------ 265.27 KiB/1.50 MiB
# aiohttp    ------------------------------ 824.56 KiB/1.60 MiB
# networkx   ------------------------------ 423.75 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (2/213)
# frozenlist ------------------------------ 16.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 32.00 KiB/277.50 KiB
# pypdf      ------------------------------ 80.00 KiB/294.96 KiB
# qdrant-client ------------------------------ 78.88 KiB/299.49 KiB
# langsmith  ------------------------------ 95.89 KiB/304.50 KiB
# protobuf   ------------------------------ 172.88 KiB/312.18 KiB
# yarl       ------------------------------ 189.17 KiB/336.08 KiB
# jiter      ------------------------------ 188.22 KiB/337.45 KiB
# tzdata     ------------------------------ 78.06 KiB/338.63 KiB
# rpds-py    ------------------------------ 370.84 KiB/377.20 KiB
# prompt-toolkit ------------------------------ 183.07 KiB/378.73 KiB
# langchain-core ------------------------------ 382.88 KiB/405.42 KiB
# openai     ------------------------------ 254.92 KiB/462.42 KiB
# pytz       ------------------------------ 158.88 KiB/496.10 KiB
# chromadb   ------------------------------ 496.18 KiB/613.62 KiB
# ipython    ------------------------------ 622.07 KiB/807.34 KiB
# langchain  ------------------------------ 140.77 KiB/987.87 KiB
# tiktoken   ------------------------------ 768.40 KiB/1.03 MiB
# pygments   ------------------------------ 780.24 KiB/1.17 MiB
# jedi       ------------------------------ 265.27 KiB/1.50 MiB
# aiohttp    ------------------------------ 856.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (12/213)
# cohere     ------------------------------ 16.00 KiB/247.99 KiB
# frozenlist ------------------------------ 16.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 62.09 KiB/277.50 KiB
# pypdf      ------------------------------ 112.00 KiB/294.96 KiB
# qdrant-client ------------------------------ 94.88 KiB/299.49 KiB
# langsmith  ------------------------------ 112.00 KiB/304.50 KiB
# protobuf   ------------------------------ 188.88 KiB/312.18 KiB
# yarl       ------------------------------ 205.17 KiB/336.08 KiB
# jiter      ------------------------------ 196.32 KiB/337.45 KiB
# tzdata     ------------------------------ 94.06 KiB/338.63 KiB
# prompt-toolkit ------------------------------ 199.07 KiB/378.73 KiB
# langchain-core ------------------------------ 392.56 KiB/405.42 KiB
# openai     ------------------------------ 254.92 KiB/462.42 KiB
# pytz       ------------------------------ 158.88 KiB/496.10 KiB
# chromadb   ------------------------------ 496.18 KiB/613.62 KiB
# ipython    ------------------------------ 638.07 KiB/807.34 KiB
# langchain  ------------------------------ 140.77 KiB/987.87 KiB
# tiktoken   ------------------------------ 776.56 KiB/1.03 MiB
# pygments   ------------------------------ 812.24 KiB/1.17 MiB
# jedi       ------------------------------ 267.89 KiB/1.50 MiB
# aiohttp    ------------------------------ 872.56 KiB/1.60 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (12/213)
# cohere     ------------------------------ 16.00 KiB/247.99 KiB
# frozenlist ------------------------------ 32.00 KiB/268.43 KiB
# bcrypt     ------------------------------ 62.09 KiB/277.50 KiB
# pypdf      ------------------------------ 112.00 KiB/294.96 KiB
# qdrant-client ------------------------------ 94.88 KiB/299.49 KiB
# langsmith  ------------------------------ 112.00 KiB/304.50 KiB
# protobuf   ------------------------------ 188.88 KiB/312.18 KiB
# yarl       ------------------------------ 205.17 KiB/336.08 KiB
# jiter      ------------------------------ 196.32 KiB/337.45 KiB
# tzdata     ------------------------------ 94.06 KiB/338.63 KiB
# prompt-toolkit ------------------------------ 199.07 KiB/378.73 KiB
# openai     ------------------------------ 254.92 KiB/462.42 KiB
# pytz       ------------------------------ 158.88 KiB/496.10 KiB
# chromadb   ------------------------------ 496.18 KiB/613.62 KiB
# ipython    ------------------------------ 638.07 KiB/807.34 KiB
# langchain  ------------------------------ 140.77 KiB/987.87 KiB
# tiktoken   ------------------------------ 776.56 KiB/1.03 MiB
# pygments   ------------------------------ 812.24 KiB/1.17 MiB
# jedi       ------------------------------ 267.89 KiB/1.50 MiB
# aiohttp    ------------------------------ 872.56 KiB/1.60 MiB
# networkx   ------------------------------ 439.64 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (12/213)
# google-cloud-bigquery ------------------------------     0 B/242.08 KiB
# openpyxl   ------------------------------     0 B/245.03 KiB
# cohere     ------------------------------ 48.00 KiB/247.99 KiB
# frozenlist ------------------------------ 62.59 KiB/268.43 KiB
# bcrypt     ------------------------------ 94.09 KiB/277.50 KiB
# pypdf      ------------------------------ 128.00 KiB/294.96 KiB
# qdrant-client ------------------------------ 126.88 KiB/299.49 KiB
# langsmith  ------------------------------ 144.00 KiB/304.50 KiB
# protobuf   ------------------------------ 232.71 KiB/312.18 KiB
# yarl       ------------------------------ 237.17 KiB/336.08 KiB
# jiter      ------------------------------ 244.32 KiB/337.45 KiB
# tzdata     ------------------------------ 94.06 KiB/338.63 KiB
# prompt-toolkit ------------------------------ 333.41 KiB/378.73 KiB
# openai     ------------------------------ 286.92 KiB/462.42 KiB
# pytz       ------------------------------ 191.59 KiB/496.10 KiB
# chromadb   ------------------------------ 571.17 KiB/613.62 KiB
# ipython    ------------------------------ 702.07 KiB/807.34 KiB
# langchain  ------------------------------ 156.98 KiB/987.87 KiB
# tiktoken   ------------------------------ 808.56 KiB/1.03 MiB
# pygments   ------------------------------ 876.24 KiB/1.17 MiB
# jedi       ------------------------------ 287.89 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠼ Preparing packages... (12/213)
# google-cloud-bigquery ------------------------------ 92.42 KiB/242.08 KiB
# openpyxl   ------------------------------ 16.00 KiB/245.03 KiB
# cohere     ------------------------------ 80.00 KiB/247.99 KiB
# frozenlist ------------------------------ 158.59 KiB/268.43 KiB
# bcrypt     ------------------------------ 158.09 KiB/277.50 KiB
# pypdf      ------------------------------ 223.89 KiB/294.96 KiB
# qdrant-client ------------------------------ 169.70 KiB/299.49 KiB
# langsmith  ------------------------------ 240.00 KiB/304.50 KiB
# protobuf   ------------------------------ 268.88 KiB/312.18 KiB
# yarl       ------------------------------ 333.06 KiB/336.08 KiB
# jiter      ------------------------------ 316.22 KiB/337.45 KiB
# tzdata     ------------------------------ 110.06 KiB/338.63 KiB
# openai     ------------------------------ 286.92 KiB/462.42 KiB
# pytz       ------------------------------ 203.35 KiB/496.10 KiB
# chromadb   ------------------------------ 587.07 KiB/613.62 KiB
# ipython    ------------------------------ 718.07 KiB/807.34 KiB
# langchain  ------------------------------ 188.98 KiB/987.87 KiB
# tiktoken   ------------------------------ 920.11 KiB/1.03 MiB
# pygments   ------------------------------ 924.24 KiB/1.17 MiB
# jedi       ------------------------------ 287.89 KiB/1.50 MiB
# aiohttp    ------------------------------ 995.56 KiB/1.60 MiB
# ...
# pyright    ------------------------------ 3.50 MiB/5.43 MiB
# numpy      ------------------------------ 10.26 MiB/15.65 MiB
# lancedb    ------------------------------ 16.27 MiB/31.10 MiB
# pylance    ------------------------------ 16.00 MiB/34.07 MiB
# ⠙ Preparing packages... (208/213) 15.38 MiB/40.13 MiB
# pyright    ------------------------------ 3.50 MiB/5.43 MiB
# numpy      ------------------------------ 10.26 MiB/15.65 MiB
# lancedb    ------------------------------ 16.27 MiB/31.10 MiB
# pylance    ------------------------------ 16.00 MiB/34.07 MiB
# ⠙ Preparing packages... (208/213) 15.40 MiB/40.13 MiB
# pyright    ------------------------------ 3.50 MiB/5.43 MiB
# numpy      ------------------------------ 10.26 MiB/15.65 MiB
# lancedb    ------------------------------ 16.27 MiB/31.10 MiB
# pylance    ------------------------------ 16.00 MiB/34.07 MiB
# ⠙ Preparing packages... (208/213) 15.42 MiB/40.13 MiB
# pyright    ------------------------------ 3.58 MiB/5.43 MiB
# numpy      ------------------------------ 10.33 MiB/15.65 MiB
# lancedb    ------------------------------ 16.27 MiB/31.10 MiB
# pylance    ------------------------------ 16.38 MiB/34.07 MiB
# ⠙ Preparing packages... (208/213) 16.47 MiB/40.13 MiB
# pyright    ------------------------------ 3.64 MiB/5.43 MiB
# numpy      ------------------------------ 12.44 MiB/15.65 MiB
# lancedb    ------------------------------ 17.42 MiB/31.10 MiB
# pylance    ------------------------------ 16.73 MiB/34.07 MiB
# ⠸ Preparing packages... (208/213) 16.62 MiB/40.13 MiB
# pyright    ------------------------------ 3.64 MiB/5.43 MiB
# numpy      ------------------------------ 12.73 MiB/15.65 MiB
# lancedb    ------------------------------ 18.86 MiB/31.10 MiB
# pylance    ------------------------------ 18.02 MiB/34.07 MiB
# ⠸ Preparing packages... (208/213) 17.89 MiB/40.13 MiB
# pyright    ------------------------------ 3.64 MiB/5.43 MiB
# numpy      ------------------------------ 12.73 MiB/15.65 MiB
# lancedb    ------------------------------ 18.86 MiB/31.10 MiB
# pylance    ------------------------------ 18.11 MiB/34.07 MiB
# ⠸ Preparing packages... (208/213) 17.89 MiB/40.13 MiB
# pyright    ------------------------------ 3.64 MiB/5.43 MiB
# numpy      ------------------------------ 12.73 MiB/15.65 MiB
# lancedb    ------------------------------ 18.86 MiB/31.10 MiB
# pylance    ------------------------------ 18.12 MiB/34.07 MiB
# ⠸ Preparing packages... (208/213) 17.89 MiB/40.13 MiB
# pyright    ------------------------------ 3.64 MiB/5.43 MiB
# numpy      ------------------------------ 12.73 MiB/15.65 MiB
# lancedb    ------------------------------ 18.86 MiB/31.10 MiB
# pylance    ------------------------------ 18.14 MiB/34.07 MiB
# ⠸ Preparing packages... (208/213) 17.89 MiB/40.13 MiB
# pyright    ------------------------------ 3.64 MiB/5.43 MiB
# numpy      ------------------------------ 13.11 MiB/15.65 MiB
# lancedb    ------------------------------ 18.86 MiB/31.10 MiB
# pylance    ------------------------------ 18.70 MiB/34.07 MiB
# ⠸ Preparing packages... (208/213) 17.89 MiB/40.13 MiB
# pyright    ------------------------------ 3.64 MiB/5.43 MiB
# numpy      ------------------------------ 13.84 MiB/15.65 MiB
# lancedb    ------------------------------ 20.30 MiB/31.10 MiB
# pylance    ------------------------------ 19.21 MiB/34.07 MiB
# ⠼ Preparing packages... (208/213) 19.56 MiB/40.13 MiB
# pyright    ------------------------------ 3.84 MiB/5.43 MiB
# numpy      ------------------------------ 13.87 MiB/15.65 MiB
# lancedb    ------------------------------ 20.55 MiB/31.10 MiB
# pylance    ------------------------------ 19.66 MiB/34.07 MiB
# ⠼ Preparing packages... (208/213) 19.83 MiB/40.13 MiB
# pyright    ------------------------------ 3.84 MiB/5.43 MiB
# numpy      ------------------------------ 13.87 MiB/15.65 MiB
# lancedb    ------------------------------ 20.64 MiB/31.10 MiB
# pylance    ------------------------------ 19.66 MiB/34.07 MiB
# ⠼ Preparing packages... (208/213) 19.83 MiB/40.13 MiB
# pyright    ------------------------------ 3.84 MiB/5.43 MiB
# numpy      ------------------------------ 13.87 MiB/15.65 MiB
# lancedb    ------------------------------ 20.66 MiB/31.10 MiB
# pylance    ------------------------------ 19.66 MiB/34.07 MiB
# ⠼ Preparing packages... (208/213) 19.83 MiB/40.13 MiB
# pyright    ------------------------------ 3.84 MiB/5.43 MiB
# numpy      ------------------------------ 13.87 MiB/15.65 MiB
# lancedb    ------------------------------ 20.67 MiB/31.10 MiB
# pylance    ------------------------------ 19.66 MiB/34.07 MiB
# ⠼ Preparing packages... (208/213) 19.83 MiB/40.13 MiB
# pyright    ------------------------------ 3.84 MiB/5.43 MiB
# numpy      ------------------------------ 14.10 MiB/15.65 MiB
# lancedb    ------------------------------ 22.19 MiB/31.10 MiB
# pylance    ------------------------------ 19.66 MiB/34.07 MiB
# ⠴ Preparing packages... (208/213) 21.37 MiB/40.13 MiB
# pyright    ------------------------------ 3.85 MiB/5.43 MiB
# numpy      ------------------------------ 14.58 MiB/15.65 MiB
# lancedb    ------------------------------ 22.70 MiB/31.10 MiB
# pylance    ------------------------------ 19.66 MiB/34.07 MiB
# ⠴ Preparing packages... (208/213) 21.37 MiB/40.13 MiB
# pyright    ------------------------------ 3.85 MiB/5.43 MiB
# numpy      ------------------------------ 14.58 MiB/15.65 MiB
# lancedb    ------------------------------ 22.70 MiB/31.10 MiB
# pylance    ------------------------------ 19.66 MiB/34.07 MiB
# ⠴ Preparing packages... (208/213) 21.38 MiB/40.13 MiB
# pyright    ------------------------------ 3.85 MiB/5.43 MiB
# numpy      ------------------------------ 14.58 MiB/15.65 MiB
# lancedb    ------------------------------ 22.70 MiB/31.10 MiB
# pylance    ------------------------------ 19.68 MiB/34.07 MiB
# ⠴ Preparing packages... (208/213) 21.41 MiB/40.13 MiB
# pyright    ------------------------------ 3.85 MiB/5.43 MiB
# numpy      ------------------------------ 14.58 MiB/15.65 MiB
# lancedb    ------------------------------ 22.80 MiB/31.10 MiB
# pylance    ------------------------------ 21.51 MiB/34.07 MiB
# ⠴ Preparing packages... (208/213) 22.30 MiB/40.13 MiB
# pyright    ------------------------------ 3.85 MiB/5.43 MiB
# numpy      ------------------------------ 14.58 MiB/15.65 MiB
# lancedb    ------------------------------ 24.12 MiB/31.10 MiB
# pylance    ------------------------------ 22.88 MiB/34.07 MiB
# ⠦ Preparing packages... (208/213) 23.96 MiB/40.13 MiB
# pyright    ------------------------------ 3.87 MiB/5.43 MiB
# numpy      ------------------------------ 14.64 MiB/15.65 MiB
# lancedb    ------------------------------ 25.37 MiB/31.10 MiB
# pylance    ------------------------------ 24.37 MiB/34.07 MiB
# ⠦ Preparing packages... (208/213) 25.43 MiB/40.13 MiB
# pyright    ------------------------------ 3.87 MiB/5.43 MiB
# numpy      ------------------------------ 14.69 MiB/15.65 MiB
# lancedb    ------------------------------ 26.97 MiB/31.10 MiB
# pylance    ------------------------------ 25.85 MiB/34.07 MiB
# ⠦ Preparing packages... (208/213) 26.71 MiB/40.13 MiB
# pyright    ------------------------------ 3.87 MiB/5.43 MiB
# numpy      ------------------------------ 14.76 MiB/15.65 MiB
# lancedb    ------------------------------ 28.17 MiB/31.10 MiB
# pylance    ------------------------------ 27.37 MiB/34.07 MiB
# ⠦ Preparing packages... (208/213) 28.60 MiB/40.13 MiB
# pyright    ------------------------------ 3.87 MiB/5.43 MiB
# numpy      ------------------------------ 14.79 MiB/15.65 MiB
# lancedb    ------------------------------ 28.73 MiB/31.10 MiB
# pylance    ------------------------------ 28.84 MiB/34.07 MiB
# ⠇ Preparing packages... (208/213) 30.73 MiB/40.13 MiB
# pyright    ------------------------------ 3.87 MiB/5.43 MiB
# numpy      ------------------------------ 14.79 MiB/15.65 MiB
# lancedb    ------------------------------ 28.73 MiB/31.10 MiB
# pylance    ------------------------------ 28.84 MiB/34.07 MiB
# ⠇ Preparing packages... (208/213) 30.86 MiB/40.13 MiB
# pyright    ------------------------------ 3.87 MiB/5.43 MiB
# numpy      ------------------------------ 14.81 MiB/15.65 MiB
# lancedb    ------------------------------ 28.73 MiB/31.10 MiB
# pylance    ------------------------------ 28.84 MiB/34.07 MiB
# ⠇ Preparing packages... (208/213) 30.86 MiB/40.13 MiB
# pyright    ------------------------------ 3.87 MiB/5.43 MiB
# numpy      ------------------------------ 14.81 MiB/15.65 MiB
# lancedb    ------------------------------ 28.84 MiB/31.10 MiB
# pylance    ------------------------------ 28.84 MiB/34.07 MiB
# ⠇ Preparing packages... (208/213) 30.86 MiB/40.13 MiB
# pyright    ------------------------------ 3.87 MiB/5.43 MiB
# numpy      ------------------------------ 14.81 MiB/15.65 MiB
# lancedb    ------------------------------ 28.86 MiB/31.10 MiB
# pylance    ------------------------------ 28.84 MiB/34.07 MiB
# ⠇ Preparing packages... (208/213) 30.86 MiB/40.13 MiB
# pyright    ------------------------------ 3.87 MiB/5.43 MiB
# numpy      ------------------------------ 14.81 MiB/15.65 MiB
# lancedb    ------------------------------ 29.81 MiB/31.10 MiB
# pylance    ------------------------------ 30.39 MiB/34.07 MiB
# ⠇ Preparing packages... (208/213) 31.61 MiB/40.13 MiB
# pyright    ------------------------------ 3.87 MiB/5.43 MiB
# numpy      ------------------------------ 14.86 MiB/15.65 MiB
# lancedb    ------------------------------ 31.07 MiB/31.10 MiB
# pylance    ------------------------------ 32.03 MiB/34.07 MiB
# ⠇ Preparing packages... (208/213) 33.08 MiB/40.13 MiB
# pyright    ------------------------------ 3.88 MiB/5.43 MiB
# numpy      ------------------------------ 14.86 MiB/15.65 MiB
# pylance    ------------------------------ 33.53 MiB/34.07 MiB
# ⠇ Preparing packages... (208/213) 33.17 MiB/40.13 MiB
# pyright    ------------------------------ 3.88 MiB/5.43 MiB
# numpy      ------------------------------ 14.89 MiB/15.65 MiB
# ⠇ Preparing packages... (208/213) 35.12 MiB/40.13 MiB
# pyright    ------------------------------ 3.88 MiB/5.43 MiB
# numpy      ------------------------------ 14.89 MiB/15.65 MiB
# ⠇ Preparing packages... (208/213) 35.87 MiB/40.13 MiB
# pyright    ------------------------------ 3.95 MiB/5.43 MiB
# ⠇ Preparing packages... (208/213) 38.45 MiB/40.13 MiB
# pyright    ------------------------------ 3.97 MiB/5.43 MiB
# ⠋ Preparing packages... (211/213) 38.49 MiB/40.13 MiB
# pyright    ------------------------------ 4.37 MiB/5.43 MiB
# ⠋ Preparing packages... (211/213) 39.70 MiB/40.13 MiB
# ⠋ Preparing packages... (211/213) 4.45 MiB/5.43 MiB
# Prepared 213 packages in 7.10s
# Installed 213 packages in 427ms
#  + aiohappyeyeballs==2.5.0
#  + aiohttp==3.11.13
#  + aiosignal==1.3.2
#  + alembic==1.15.1
#  + annotated-types==0.7.0
#  + anyio==4.8.0
#  + appdirs==1.4.4
#  + asgiref==3.8.1
#  + asttokens==3.0.0
#  + attrs==25.1.0
#  + auth0-python==4.8.1
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + beautifulsoup4==4.13.3
#  + blinker==1.9.0
#  + build==1.2.2.post1
#  + cachetools==5.5.2
#  + certifi==2025.1.31
#  + cffi==1.17.1
#  + charset-normalizer==3.4.1
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + click==8.1.8
#  + cohere==5.14.0
#  + coloredlogs==15.0.1
#  + crewai==0.102.0
#  + crewai-tools==0.36.0
#  + cryptography==44.0.2
#  + dataclasses-json==0.6.7
#  + decorator==5.2.1
#  + deprecated==1.2.18
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.16
#  + durationpy==0.9
#  + embedchain==0.1.127
#  + et-xmlfile==2.0.0
#  + executing==2.2.0
#  + fastapi==0.115.11
#  + fastavro==1.10.0
#  + filelock==3.17.0
#  + flatbuffers==25.2.10
#  + frozenlist==1.5.0
#  + fsspec==2025.2.0
#  + google-api-core==2.24.1
#  + google-auth==2.38.0
#  + google-cloud-aiplatform==1.83.0
#  + google-cloud-bigquery==3.30.0
#  + google-cloud-core==2.4.2
#  + google-cloud-resource-manager==1.14.1
#  + google-cloud-storage==2.19.0
#  + google-crc32c==1.6.0
#  + google-resumable-media==2.7.2
#  + googleapis-common-protos==1.69.0
#  + gptcache==0.1.44
#  + greenlet==3.1.1
#  + grpc-google-iam-v1==0.14.1
#  + grpcio==1.70.0
#  + grpcio-status==1.70.0
#  + grpcio-tools==1.70.0
#  + h11==0.14.0
#  + h2==4.2.0
#  + hpack==4.1.0
#  + httpcore==1.0.7
#  + httptools==0.6.4
#  + httpx==0.27.2
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.29.2
#  + humanfriendly==10.0
#  + hyperframe==6.1.0
#  + idna==3.10
#  + importlib-metadata==8.5.0
#  + importlib-resources==6.5.2
#  + instructor==1.7.2
#  + ipython==8.33.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.8.2
#  + json-repair==0.39.1
#  + json5==0.10.0
#  + jsonpatch==1.33
#  + jsonpickle==4.0.2
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.23.0
#  + jsonschema-specifications==2024.10.1
#  + kubernetes==32.0.1
#  + lancedb==0.20.0
#  + langchain==0.3.20
#  + langchain-cohere==0.3.5
#  + langchain-community==0.3.19
#  + langchain-core==0.3.41
#  + langchain-experimental==0.3.4
#  + langchain-openai==0.2.14
#  + langchain-text-splitters==0.3.6
#  + langsmith==0.1.147
#  + litellm==1.60.2
#  + mako==1.3.9
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.26.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.65
#  + mmh3==5.1.0
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.1.0
#  + mypy-extensions==1.0.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==2.2.3
#  + oauthlib==3.2.2
#  + onnxruntime==1.20.1
#  + openai==1.65.4
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.30.0
#  + opentelemetry-exporter-otlp-proto-common==1.30.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.30.0
#  + opentelemetry-exporter-otlp-proto-http==1.30.0
#  + opentelemetry-instrumentation==0.51b0
#  + opentelemetry-instrumentation-asgi==0.51b0
#  + opentelemetry-instrumentation-fastapi==0.51b0
#  + opentelemetry-proto==1.30.0
#  + opentelemetry-sdk==1.30.0
#  + opentelemetry-semantic-conventions==0.51b0
#  + opentelemetry-util-http==0.51b0
#  + orjson==3.10.15
#  + overrides==7.7.0
#  + packaging==24.2
#  + pandas==2.2.3
#  + parso==0.8.4
#  + pdfminer-six==20231228
#  + pdfplumber==0.11.5
#  + pexpect==4.9.0
#  + pillow==11.1.0
#  + portalocker==2.10.1
#  + posthog==3.18.1
#  + prompt-toolkit==3.0.50
#  + propcache==0.3.0
#  + proto-plus==1.26.0
#  + protobuf==5.29.3
#  + psycopg2-binary==2.9.10
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==19.0.1
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.1
#  + pycparser==2.22
#  + pydantic==2.10.6
#  + pydantic-core==2.27.2
#  + pydantic-settings==2.8.1
#  + pygments==2.19.1
#  + pyjwt==2.10.1
#  + pylance==0.23.2
#  + pypdf==5.3.1
#  + pypdfium2==4.30.1
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.396
#  + pysbd==0.3.4
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.0.1
#  + pytube==15.0.0
#  + pytz==2024.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.13.3
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.3
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.23.1
#  + rsa==4.9
#  + schema==0.7.7
#  + setuptools==75.8.2
#  + shapely==2.0.7
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.6
#  + sqlalchemy==2.0.38
#  + stack-data==0.6.3
#  + starlette==0.46.0
#  + sympy==1.13.3
#  + tabulate==0.9.0
#  + tenacity==9.0.0
#  + tiktoken==0.7.0
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typer==0.15.2
#  + types-requests==2.32.0.20250306
#  + typing-extensions==4.12.2
#  + typing-inspect==0.9.0
#  + tzdata==2025.1
#  + urllib3==2.3.0
#  + uv==0.6.4
#  + uvicorn==0.34.0
#  + uvloop==0.21.0
#  + watchfiles==1.0.4
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==15.0.1
#  + wrapt==1.17.2
#  + yarl==1.18.3
#  + zipp==3.21.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# # Agent: AI LLMs Senior Data Researcher
# ## Task: Conduct a thorough research about AI LLMs Make sure you find any interesting and relevant information given the current year is 2024.
#
#
#
# # Agent: AI LLMs Senior Data Researcher
# ## Final Answer:
# - **Advancements in Multimodal Models**: 2024 has seen significant progress in multimodal AI LLMs, which combine text with images, audio, and video to create more comprehensive understanding and interaction. OpenAI's 'CLIP' and Google's 'Imagen' are prime examples that enable rich content generation and interpretation across various media formats.
#
# - **Increased Focus on Ethical AI**: Discussions surrounding the ethical implications of AI LLMs have intensified. Researchers are focusing on bias mitigation, transparency, and accountability to guide the development of more responsible AI systems, ensuring fairness and reducing harm in automated decision-making processes.
#
# - **Foundation Models**: Organizations are emphasizing the development of foundation models that serve as the cornerstone for various applications. These models are pre-trained on vast datasets and can be fine-tuned for specific tasks, leading to efficiency in AI application deployment across industries.
#
# - **Real-Time Language Translation Improvements**: Advances in AI LLMs have led to real-time translation capabilities that are more accurate and context-aware, making it feasible for businesses to operate globally without language barriers. Commercial applications are seeing increased demand for these tools in customer support and content localization.
#
# - **Integration of AI in Software Development**: The advent of AI pair programming tools, like GitHub Copilot, showcases how AI LLMs are enhancing productivity for software developers. These tools provide intelligent code suggestions and help debug errors, streamlining the programming process.
#
# - **Expanded Applications in Healthcare**: AI LLMs are being increasingly utilized in the healthcare sector for tasks such as patient triage through chatbots, transcription of doctor-patient interactions, and analysis of medical literature, enhancing efficiency and patient outcomes.
#
# - **Improved Natural Language Understanding (NLU)**: The accuracy of NLU has seen dramatic improvements in 2024, enabling AI systems to interpret and generate human-like responses in more complex conversations, thereby enhancing user experience in digital assistants and customer service applications.
#
# - **Environmental Considerations and Sustainability**: There is a growing movement toward developing energy-efficient AI LLMs that minimize their carbon footprint. Research is focusing on algorithmic efficiency in training and operating models, addressing environmental impacts associated with AI technology.
#
# - **Development of Open Source Models**: The trend towards open-source AI LLMs is gaining traction, with communities building and sharing powerful models. Initiatives like Hugging Face and EleutherAI are democratizing access to AI technologies, allowing developers around the world to innovate together.
#
# - **Regulation and Policy Frameworks**: Governments and organizations are beginning to implement regulations and standards for the deployment of AI LLMs. This comprises data privacy laws, guidelines for responsible AI use, and frameworks to ensure interoperability and security, shaping the future landscape of AI deployment.
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Task: Review the context you got and expand each topic into a full section for a report. Make sure the report is detailed and contains any and all relevant information.
#
#
#
# # Agent: AI LLMs Reporting Analyst
# ## Final Answer:
# # Report on Recent Developments in AI LLMs (2024)
#
# ## Advancements in Multimodal Models
# In 2024, the field of artificial intelligence has experienced significant advancements in multimodal models. These models integrate various types of data, including text, images, audio, and video, allowing for a more comprehensive understanding and interaction with content. Notable examples include OpenAI's ‘CLIP’ and Google's ‘Imagen’, which facilitate rich content generation and interpretation across diverse media formats. This multimodal approach enhances applications ranging from content creation to advanced machine learning tasks, enabling AI systems to comprehend and produce outputs that resonate with human experiences. The implications of such advancements are profound, as they pave the way for more intuitive and interactive AI applications that can engage users in diverse environments.
#
# ## Increased Focus on Ethical AI
# As AI technologies proliferate, there has been an intensified focus on the ethical implications associated with AI LLMs. Researchers are increasingly concerned with issues of bias, transparency, and accountability, working to develop frameworks and guidelines aimed at fostering responsible AI systems. This includes initiatives to mitigate biases in training datasets, ensuring that AI decision-making processes are fair and reduce harm to individuals and communities. Ethical AI development is becoming a fundamental aspect of research and implementation, highlighting the necessity for AI systems to uphold values of fairness and responsibility, while maintaining public trust in automated technologies.
#
# ## Foundation Models
# Foundation models are gaining prominence as the vital backbone for various AI applications. These models are pre-trained on expansive datasets, enabling them to be fine-tuned for specific tasks with relative ease and efficiency. The ability to leverage foundation models reduces the duplication of efforts and expedites the deployment of AI solutions across different industries. With their general-purpose capabilities, these models serve as a powerful starting point, facilitating innovation while enabling organizations to harness the full potential of AI technologies in customized manners according to their specific needs.
#
# ## Real-Time Language Translation Improvements
# Advancements in AI LLMs have markedly improved real-time language translation capabilities, making them more accurate and context-aware. These improvements enable businesses to operate globally without facing significant language barriers. Tools that provide instant translation are becoming imperative for customer support and content localization, allowing companies to interact with customers from diverse linguistic backgrounds seamlessly. The demand for such tools is rapidly increasing, contributing to greater inclusivity and efficiency in international business operations.
#
# ## Integration of AI in Software Development
# AI LLMs are transforming software development through the introduction of AI pair programming tools, such as GitHub Copilot. These tools enhance the productivity of developers by providing intelligent code suggestions, identifying bugs or potential issues, and streamlining the coding process. AI assistance minimizes repetitive tasks, enabling developers to focus on more complex challenges and fostering a collaborative development environment. This integration signifies a shift in the software development landscape, where human creativity and AI support synergistically boost innovation.
#
# ## Expanded Applications in Healthcare
# The healthcare sector has increasingly adopted AI LLMs for various functions, including patient triage via chatbots, transcription of doctor-patient interactions, and analysis of extensive medical literature. These applications improve efficiency, reduce administrative burdens, and enhance patient outcomes. By automating routine tasks and providing insights drawn from vast datasets, AI is revolutionizing how healthcare professionals operate, allowing them to devote more attention to patient care and decision-making.
#
# ## Improved Natural Language Understanding (NLU)
# 2024 saw dramatic advancements in Natural Language Understanding (NLU), where AI systems can interpret and generate human-like responses in more complex conversations. This capability significantly enhances user interactions within digital assistants, chatbots, and customer service platforms. As NLU systems become more sophisticated, they enable more natural, engaging, and effective communication between humans and machines, making AI a more integral part of daily interactions.
#
# ## Environmental Considerations and Sustainability
# A growing movement toward developing energy-efficient AI LLMs is addressing concerns about the environmental impact of AI technologies. Researchers are focusing on algorithmic efficiency and the sustainability of practices associated with training and operating these models. By minimizing their carbon footprint, the AI community is promoting a more responsible approach to technology development, addressing the environmental challenges associated with increased computational demands of AI.
#
# ## Development of Open Source Models
# The trend toward open-source AI LLMs is gaining momentum, fostering a collaborative environment within the developer community. Platforms such as Hugging Face and EleutherAI are democratizing access to powerful AI technologies, allowing developers worldwide to contribute and innovate. This shift enables greater transparency, promotes collaborative projects, and accelerates advancements in AI capabilities, as knowledge and resources are shared across borders and backgrounds.
#
# ## Regulation and Policy Frameworks
# Governments and organizations are beginning to implement regulations and standards governing the deployment of AI LLMs. This includes developing data privacy laws, drafting guidelines for responsible AI usage, and establishing frameworks to ensure interoperability and security in AI applications. Such regulatory efforts are essential for shaping a landscape that emphasizes ethical AI development, ensuring the protection of users and fostering trust in AI technologies as they become increasingly integrated into society.
#
# This comprehensive report encapsulates the current landscape of AI LLMs, illustrating a rapidly evolving field characterized by remarkable advancements, ethical considerations, and the imperative for responsible use. As 2024 unfolds, these developments will undoubtedly continue to shape the trajectory of AI technologies and their integration into various aspects of life and industry.

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
